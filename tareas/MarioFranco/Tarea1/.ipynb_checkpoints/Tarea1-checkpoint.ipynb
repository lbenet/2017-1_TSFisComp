# %%
using Images
# Out:
# INFO: Recompiling stale cache file C:\Users\Franco\.julia\lib\v0.4\Rmath.ji for module Rmath.
# INFO: Recompiling stale cache file C:\Users\Franco\.julia\lib\v0.4\StatsFuns.ji for module StatsFuns.
# INFO: Recompiling stale cache file C:\Users\Franco\.julia\lib\v0.4\StatsBase.ji for module StatsBase.
# INFO: Recompiling stale cache file C:\Users\Franco\.julia\lib\v0.4\Images.ji for module Images.

# %% [markdown]
# # Introduction sequence

# %% [markdown]
# Ejercicio 3

# %%
Proff_1 = load("IntroctionSequence_3.png")
# Out:
# RGB Images.Image with:
#   data: 1600x500 Array{ColorTypes.RGB{FixedPointNumbers.UFixed{UInt8,8}},2}
#   properties:
#     colorspace: sRGB
#     spatialorder:  x y

# %% [raw]
# git branch bugFix
# git checkout bugFix
# git commit -m "BugFix"
# git checkout master
# git commit -m "Master"
# git merge bugFix

# %% [markdown]
# Ejercicio 4

# %%
Proff_2 = load("IntroctionSequence_4.png")
# Out:
# RGB Images.Image with:
#   data: 1600x500 Array{ColorTypes.RGB{FixedPointNumbers.UFixed{UInt8,8}},2}
#   properties:
#     colorspace: sRGB
#     spatialorder:  x y

# %% [raw]
# git branch bugFix
# git checkout bugFix
# git commit -m "BugFix"
# git checkout master
# git commit -m "Master"
# git checkout bugFix
# git rebase master

# %% [markdown]
# # Ramping up

# %% [markdown]
# Ejercicio 3

# %%
Proff_2 = load("RampingUp_3.png")
# Out:
# RGB Images.Image with:
#   data: 1600x500 Array{ColorTypes.RGB{FixedPointNumbers.UFixed{UInt8,8}},2}
#   properties:
#     colorspace: sRGB
#     spatialorder:  x y

# %% [raw]
# git checkout HEAD^
# git branch -f master C6
# git branch -f bugFix HEAD^

# %% [markdown]
# Ejercicio 4

# %%
Proff_2 = load("RampingUp_4.png")
# Out:
# RGB Images.Image with:
#   data: 1600x500 Array{ColorTypes.RGB{FixedPointNumbers.UFixed{UInt8,8}},2}
#   properties:
#     colorspace: sRGB
#     spatialorder:  x y

# %% [raw]
# git reset master
# git checkout pushed
# git revert HEAD
