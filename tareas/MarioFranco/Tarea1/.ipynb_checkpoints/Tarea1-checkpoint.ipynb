# %%
using Images

# %% [markdown]
# # Introduction sequence

# %% [markdown]
# Ejercicio 3

# %%
Proff_1 = load("IntroctionSequence_3.png")
# Out:
# BGRA Images.Image with:
#   data: 1600x600 Array{ColorTypes.BGRA{FixedPointNumbers.UFixed{UInt8,8}},2}
#   properties:
#     colorspace: sRGB
#     spatialorder:  x y

# %% [raw]
# git branch bugFix
# git checkout bugFix
# git commit -m "BugFix"
# git checkout master
# git commit -m "Master"
# git merge bugFix

# %% [markdown]
# Ejercicio 4

# %%
Proff_2 = load("IntroctionSequence_4.png")
# Out:
# BGRA Images.Image with:
#   data: 1600x620 Array{ColorTypes.BGRA{FixedPointNumbers.UFixed{UInt8,8}},2}
#   properties:
#     colorspace: sRGB
#     spatialorder:  x y

# %% [raw]
# git branch bugFix
# git checkout bugFix
# git commit -m "BugFix"
# git checkout master
# git commit -m "Master"
# git checkout bugFix
# git rebase master

# %% [markdown]
# # Ramping up

# %% [markdown]
# Ejercicio 3

# %%
Proff_3 = load("RampingUp_3.png")
# Out:
# BGRA Images.Image with:
#   data: 1600x600 Array{ColorTypes.BGRA{FixedPointNumbers.UFixed{UInt8,8}},2}
#   properties:
#     colorspace: sRGB
#     spatialorder:  x y

# %% [raw]
# git checkout HEAD^
# git branch -f master C6
# git branch -f bugFix HEAD^

# %% [markdown]
# Ejercicio 4

# %%
Proff_4 = load("RampingUp_4.png")
# Out:
# BGRA Images.Image with:
#   data: 1600x600 Array{ColorTypes.BGRA{FixedPointNumbers.UFixed{UInt8,8}},2}
#   properties:
#     colorspace: sRGB
#     spatialorder:  x y

# %% [raw]
# git reset master
# git checkout pushed
# git revert HEAD

# %% [markdown]
# # Moving work around

# %% [markdown]
# Ejercicio 1

# %%
Proff_5 = load("MovingWorkAround_1.png")
# Out:
# BGRA Images.Image with:
#   data: 1600x640 Array{ColorTypes.BGRA{FixedPointNumbers.UFixed{UInt8,8}},2}
#   properties:
#     colorspace: sRGB
#     spatialorder:  x y

# %% [raw]
# git cherry-pick C3 C4 C7

# %% [markdown]
# Ejercicio 2

# %%
Proff_6 = load("MovingWorkAround_2.png")
# Out:
# BGRA Images.Image with:
#   data: 1600x600 Array{ColorTypes.BGRA{FixedPointNumbers.UFixed{UInt8,8}},2}
#   properties:
#     colorspace: sRGB
#     spatialorder:  x y

# %% [raw]
# git rebase -i overHere

# %% [markdown]
# # A mixed bag

# %% [markdown]
# Ejercicio 1

# %%
Proff_7 = load("MixedBag_1.png")
# Out:
# BGRA Images.Image with:
#   data: 1600x600 Array{ColorTypes.BGRA{FixedPointNumbers.UFixed{UInt8,8}},2}
#   properties:
#     colorspace: sRGB
#     spatialorder:  x y

# %% [raw]
# git rebase -i C1
# git branch -f master C4'

# %% [markdown]
# Ejercicio 3

# %%
Proff_8 = load("MixedBag_3.png")
# Out:
# BGRA Images.Image with:
#   data: 1600x600 Array{ColorTypes.BGRA{FixedPointNumbers.UFixed{UInt8,8}},2}
#   properties:
#     colorspace: sRGB
#     spatialorder:  x y

# %% [raw]
# git checkout master
# git cheery-pick C2
# git commit --amend
# git cherry-pick C3

# %% [markdown]
# Ejercicio 4

# %%
Proff_8 = load("MixedBag_4.png")
# Out:
# BGRA Images.Image with:
#   data: 1600x600 Array{ColorTypes.BGRA{FixedPointNumbers.UFixed{UInt8,8}},2}
#   properties:
#     colorspace: sRGB
#     spatialorder:  x y

# %% [raw]
# git tag v0 C1
# git tag v1 C2
# git checkout v1

# %% [markdown]
# # Advanced topics

# %% [markdown]
# Ejercicio 2

# %%
Proff_9 = load("AdvancedTopics_2.png")
# Out:
# BGRA Images.Image with:
#   data: 1600x639 Array{ColorTypes.BGRA{FixedPointNumbers.UFixed{UInt8,8}},2}
#   properties:
#     colorspace: sRGB
#     spatialorder:  x y

# %% [raw]
# git branch bugWork HEAD~^2~

# %% [markdown]
# Ejercicio 3

# %%
Proff_10 = load("AdvancedTopics_3.png")
# Out:
# BGRA Images.Image with:
#   data: 1600x630 Array{ColorTypes.BGRA{FixedPointNumbers.UFixed{UInt8,8}},2}
#   properties:
#     colorspace: sRGB
#     spatialorder:  x y

# %% [raw]
# git checkout one
# git cherry-pick C4 C3 C2
# git checkout two
# git cherry-pick C5 C4 C3 C2
# git branch -f three C2
